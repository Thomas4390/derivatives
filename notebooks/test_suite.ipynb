# %% [markdown]
# # Running the dorion_francois tests

# %%
# %matplotlib inline
import internal_script

import sys

from dorion_francois.toolkit import print_versions
from dorion_francois.test_suite import run_tests

print_versions() # Versions of the critical dependencies
# Out:
# Python: 3.9.19
# Numpy: 1.22.3
# Pandas: 2.0.3

# %% [markdown]
# Eventually, the next cell might (should?) be replaced by a command line execution of test_suite.py. Paths are issue however. So, right now, working with a notebook allows for easier debugging.

# %%
# Run all tests
run_tests('garch')
# Out:
# /Users/christian/Dropbox/delta_vega/dv_christian/dorion_francois/garch.py:101: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   model.data = pdr.get_data_famafrench('F-F_Research_Data_Factors_daily', start='1900-01-01')[0]
# Starting from time_t0: 2018-01-02 00:00:00
# /Users/christian/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:48: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ./Users/christian/Dropbox/delta_vega/dv_christian/dorion_francois/garch.py:101: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
# ...

# %%
# Alternatively:
from dorion_francois.garch import TestGarch

# Update all
if False:
    run_tests('garch', '--update') 

# Update a single test
if False:
    TestGarch().test_agarch(update=True)

# Debug a single failed test
if False:
    tests = TestGarch()
    tests.debug = True
    tests.test_ngarch(update=False)

# %%
if False: # Set True if the above test fails
    import pickle
    path_to_expected_results = 'data/test/garch/test_ngarch.pkl'
    with open(path_to_expected_results, 'rb') as fh: 
        expected_results = pickle.load(fh)
    with open(path_to_expected_results.replace('garch/','garch/testing/'), 'rb') as fh: 
        results = pickle.load(fh)
    diff = results - expected_results
