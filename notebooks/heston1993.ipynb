# %%
# %matplotlib inline
import internal_script

import numpy as np
import warnings
from dorion_francois.heston1993 import *

# %%
def figures_2_and_4():
    prefix = ['Figure 2','Figure 2 in IV','Figure 4','Figure 4 in IV']            

    # Use the parameters in Heston (1993, RFS)
    figures_rho_sigma([-0.5,+0.5], 0.1, 0.0, [0.1, 0.2], prefix)
    
figures_2_and_4()

# %%
# Don't hesitate to play with the parameters (and even modify the function to investigate other interactions!)
figures_rho_sigma([-0.90,-0.35], 0.3, 0, [0.3, 0.2])
